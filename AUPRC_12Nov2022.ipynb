# %% [markdown]
# <a href="https://colab.research.google.com/github/prakashraaz/cornell-cs5785-applied-ml/blob/main/AUPRC_12Nov2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PR curve is a function of precision (y) and recall (x)
#
# x = Recall = TP/(TP + FN) = sensitivity = True positive rate
#
# y = Precision = TP/(TP + FP)

# %% [markdown]
# ![Screen Shot 2022-11-13 at 5.50.39 PM.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screen Shot 2022-11-13 at 5.57.40 PM.jpg](data:image/jpeg;base64,...)
